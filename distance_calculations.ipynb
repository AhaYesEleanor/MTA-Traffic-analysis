# %%
import pandas as pd
import pickle
from haversine import haversine

# %%
with open('foursquare_POIs_only.pickle', 'rb') as f:
    fsq_df = pickle.load(f)

# %%
fsq_df = fsq_df[['venueId','venueCategory', 'latitude', 'longitude']].rename(columns={'latitude':'poi_lat', 'longitude':'poi_lon'})

# %%
fsq_df.shape
# Out:
# (7523, 4)

# %%
#reducing observations to unique venues/POIs for distance calculation
fsq_df_unique = fsq_df.groupby(by='venueId', as_index=False).max()
fsq_df_unique.shape
# Out:
# (2553, 4)

# %%
with open('Benson_full_analysis.pickle', 'rb') as f:
    entry_df = pickle.load(f)

# %%
entry_df = entry_df.sort_values('ENTRIES', ascending = False)

#only interested in top 10 stations
entry_df = entry_df.iloc[0:10]

# %%
#only interested in the station names and orders
distance_df = pd.DataFrame(entry_df.STATION)
distance_df.rename(columns={'STATION': 'station'}, inplace=True)

# %%
#manually update latitude/longitude for top 10
stat_lat_lons =[(40.750497,-73.990877), #34 st- penn station
                (40.752962,-73.977219), # grand central - 42 st
                (40.750326,-73.988067), # 34 st - Herald Square
                (40.744376,-73.995652), #23 st - assuming 7th Ave and 23rd st 
                (40.735101,-73.990758), #14th st- union square
                (40.758092,-73.991457), # 42 st - port authority
                (40.709609,-74.008294), # Fulton
                (40.755453,-73.987285), # Times Square - 42nd st
                (40.789614,-73.976299), # 86 St
                (40.804609,-73.937456) #125 st
]

# %%
distance_df['station_lat'] = [x[0] for x in stat_lat_lons]
distance_df['station_lon'] = [x[1] for x in stat_lat_lons]
distance_df
# Out:
#              station  station_lat  station_lon
# 60    34 ST-PENN STA    40.750497   -73.990877
# 232  GRD CNTRL-42 ST    40.752962   -73.977219
# 58   34 ST-HERALD SQ    40.750326   -73.988067
# 45             23 ST    40.744376   -73.995652
# 14    14 ST-UNION SQ    40.735101   -73.990758
# 67   42 ST-PORT AUTH    40.758092   -73.991457
# 225        FULTON ST    40.709609   -74.008294
# 352   TIMES SQ-42 ST    40.755453   -73.987285
# 109            86 ST    40.789614   -73.976299
# 9             125 ST    40.804609   -73.937456

# %%
#add column of all 1s to each df so we can merge to get all distances
distance_df['merge_column'] = 1
fsq_df_unique['merge_column'] = 1

# %%
distance_df = distance_df.merge(right=fsq_df_unique, on='merge_column')

# %%
distance_df.drop('merge_column', axis=1, inplace=True)

# %%
distance_df.head()
# Out:
#           station  station_lat  station_lon                   venueId  \
# 0  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a5200eea1ee3
# 1  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a5200fea1ee3
# 2  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a52010e41ee3
# 3  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a5201ae61ee3
# 4  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a5201be61ee3
#
#                      venueCategory    poi_lat    poi_lon
# 0                 Sushi Restaurant  40.727771 -74.000337
# 1                      Salad Place  40.739980 -73.986648
# 2  Molecular Gastronomy Restaurant  40.719649 -73.984607
# 3                 Sushi Restaurant  40.728898 -73.998128
# 4                   Clothing Store  40.722283 -73.999529

# %%
def distance_to_station(df_row):
    station_lat = df_row.station_lat
    station_lon = df_row.station_lon
    poi_lat = df_row.poi_lat
    poi_lon = df_row.poi_lon
    stat_coords = (station_lat, station_lon)
    poi_coords = (poi_lat, poi_lon)
    return haversine(stat_coords, poi_coords, miles=True)

# %%
distance_df['distance'] = distance_df.apply(distance_to_station, axis=1)

# %%
distance_df.head()
# Out:
#           station  station_lat  station_lon                   venueId  \
# 0  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a5200eea1ee3
# 1  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a5200fea1ee3
# 2  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a52010e41ee3
# 3  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a5201ae61ee3
# 4  34 ST-PENN STA    40.750497   -73.990877  3fd66200f964a5201be61ee3
#
#                      venueCategory    poi_lat    poi_lon  distance
# 0                 Sushi Restaurant  40.727771 -74.000337  1.646483
# 1                      Salad Place  40.739980 -73.986648  0.759627
# 2  Molecular Gastronomy Restaurant  40.719649 -73.984607  2.156551
# 3                 Sushi Restaurant  40.728898 -73.998128  1.539851
# 4                   Clothing Store  40.722283 -73.999529  2.001352

# %%
distance_df = distance_df[distance_df.distance<1]
distance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3747 entries, 1 to 25462
# Data columns (total 8 columns):
# station          3747 non-null object
# station_lat      3747 non-null float64
# station_lon      3747 non-null float64
# venueId          3747 non-null object
# venueCategory    3747 non-null object
# poi_lat          3747 non-null float64
# poi_lon          3747 non-null float64
# distance         3747 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 263.5+ KB

# %%
with open('distance_df_unique.pickle','wb') as f:
    pickle.dump(distance_df, f)

# %%
distance_df.groupby(by=['venueCategory','station'], as_index=False).count().sort_values(['venueCategory','poi_lat'], ascending=[True,False])
# Out:
#           venueCategory          station  station_lat  station_lon  venueId  \
# 4          Antique Shop  42 ST-PORT AUTH            4            4        4
# 6          Antique Shop   TIMES SQ-42 ST            4            4        4
# 0          Antique Shop   14 ST-UNION SQ            3            3        3
# 5          Antique Shop  GRD CNTRL-42 ST            3            3        3
# 1          Antique Shop            23 ST            2            2        2
# 2          Antique Shop  34 ST-HERALD SQ            1            1        1
# 3          Antique Shop   34 ST-PENN STA            1            1        1
# 9           Bridal Shop  34 ST-HERALD SQ            5            5        5
# 7           Bridal Shop   14 ST-UNION SQ            4            4        4
# 8           Bridal Shop            23 ST            4            4        4
# 10          Bridal Shop   34 ST-PENN STA            4            4        4
# 11          Bridal Shop  42 ST-PORT AUTH            4            4        4
# 13          Bridal Shop   TIMES SQ-42 ST            4            4        4
# 12          Bridal Shop  GRD CNTRL-42 ST            3            3        3
# 15       Clothing Store   14 ST-UNION SQ          313          313      313
# 17       Clothing Store  34 ST-HERALD SQ          219          219      219
# 16       Clothing Store            23 ST          212          212      212
# 18       Clothing Store   34 ST-PENN STA          212          212      212
# 22       Clothing Store  GRD CNTRL-42 ST          194          194      194
# 23       Clothing Store   TIMES SQ-42 ST          183          183      183
# 19       Clothing Store  42 ST-PORT AUTH          166          166      166
# 21       Clothing Store        FULTON ST           56           56       56
# 20       Clothing Store            86 ST           20           20       20
# 14       Clothing Store           125 ST            9            9        9
# 25       Cosmetics Shop   14 ST-UNION SQ           60           60       60
# 26       Cosmetics Shop            23 ST           60           60       60
# 28       Cosmetics Shop   34 ST-PENN STA           53           53       53
# 27       Cosmetics Shop  34 ST-HERALD SQ           51           51       51
# 32       Cosmetics Shop  GRD CNTRL-42 ST           43           43       43
# 33       Cosmetics Shop   TIMES SQ-42 ST           43           43       43
# ..                  ...              ...          ...          ...      ...
# 81   Salon / Barbershop   14 ST-UNION SQ           96           96       96
# 88   Salon / Barbershop  GRD CNTRL-42 ST           72           72       72
# 82   Salon / Barbershop            23 ST           69           69       69
# 84   Salon / Barbershop   34 ST-PENN STA           67           67       67
# 89   Salon / Barbershop   TIMES SQ-42 ST           67           67       67
# 83   Salon / Barbershop  34 ST-HERALD SQ           66           66       66
# 85   Salon / Barbershop  42 ST-PORT AUTH           50           50       50
# 87   Salon / Barbershop        FULTON ST           19           19       19
# 80   Salon / Barbershop           125 ST            8            8        8
# 86   Salon / Barbershop            86 ST            6            6        6
# 91        Spa / Massage   14 ST-UNION SQ           64           64       64
# 92        Spa / Massage            23 ST           53           53       53
# 99        Spa / Massage   TIMES SQ-42 ST           46           46       46
# 94        Spa / Massage   34 ST-PENN STA           45           45       45
# 98        Spa / Massage  GRD CNTRL-42 ST           44           44       44
# 93        Spa / Massage  34 ST-HERALD SQ           42           42       42
# 95        Spa / Massage  42 ST-PORT AUTH           33           33       33
# 97        Spa / Massage        FULTON ST           16           16       16
# 96        Spa / Massage            86 ST            5            5        5
# 90        Spa / Massage           125 ST            4            4        4
# 101    Sushi Restaurant   14 ST-UNION SQ           74           74       74
# 103    Sushi Restaurant  34 ST-HERALD SQ           60           60       60
# 104    Sushi Restaurant   34 ST-PENN STA           59           59       59
# 109    Sushi Restaurant   TIMES SQ-42 ST           58           58       58
# 108    Sushi Restaurant  GRD CNTRL-42 ST           55           55       55
# 102    Sushi Restaurant            23 ST           50           50       50
# 105    Sushi Restaurant  42 ST-PORT AUTH           44           44       44
# 107    Sushi Restaurant        FULTON ST           12           12       12
# 106    Sushi Restaurant            86 ST            8            8        8
# 100    Sushi Restaurant           125 ST            1            1        1
#
#      poi_lat  poi_lon  distance
# 4          4        4         4
# 6          4        4         4
# 0          3        3         3
# 5          3        3         3
# 1          2        2         2
# 2          1        1         1
# 3          1        1         1
# 9          5        5         5
# 7          4        4         4
# 8          4        4         4
# 10         4        4         4
# 11         4        4         4
# 13         4        4         4
# 12         3        3         3
# 15       313      313       313
# 17       219      219       219
# 16       212      212       212
# 18       212      212       212
# 22       194      194       194
# 23       183      183       183
# 19       166      166       166
# 21        56       56        56
# 20        20       20        20
# 14         9        9         9
# 25        60       60        60
# 26        60       60        60
# 28        53       53        53
# 27        51       51        51
# 32        43       43        43
# 33        43       43        43
# ..       ...      ...       ...
# 81        96       96        96
# 88        72       72        72
# 82        69       69        69
# 84        67       67        67
# 89        67       67        67
# 83        66       66        66
# 85        50       50        50
# 87        19       19        19
# 80         8        8         8
# 86         6        6         6
# 91        64       64        64
# 92        53       53        53
# 99        46       46        46
# 94        45       45        45
# 98        44       44        44
# 93        42       42        42
# 95        33       33        33
# 97        16       16        16
# 96         5        5         5
# 90         4        4         4
# 101       74       74        74
# 103       60       60        60
# 104       59       59        59
# 109       58       58        58
# 108       55       55        55
# 102       50       50        50
# 105       44       44        44
# 107       12       12        12
# 106        8        8         8
# 100        1        1         1
#
# [110 rows x 8 columns]
