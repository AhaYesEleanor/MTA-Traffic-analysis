# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
# %matplotlib inline

# %%
with open('final_station_priorities_v2.pickle','rb') as read_file:
    station_priorities = pickle.load(read_file)

# %%
station_priorities.sort_values('avg_entries', ascending=False, inplace=True)
station_priorities = station_priorities.reset_index()
station_priorities
# Out:
#    level_0  index          station  avg_entries  nearby_poi_count  \
# 0        0      3   34 ST-PENN STA       784022               498
# 1        1      7  GRD CNTRL-42 ST       720653               483
# 2        2      2  34 ST-HERALD SQ       594431               506
# 3        3      1            23 ST       546372               515
# 4        4      0   14 ST-UNION SQ       521808               673
# 5        5      6        FULTON ST       496950               129
# 6        6      9   TIMES SQ-42 ST       463714               468
# 7        7      5   59 ST COLUMBUS       347784               318
# 8        8      8     PATH NEW WTC       289834               218
# 9        9      4   47-50 STS ROCK       255785               484
#
#    entry_weight  poi_weight  combined_weight_product  combined_weight_sum  \
# 0      0.156138    0.116030                 0.018117             0.272167
# 1      0.143518    0.112535                 0.016151             0.256053
# ...

# %%
import seaborn as sns
sns.set_color_codes("pastel")
sns.barplot(y=station_priorities['station'], x=station_priorities['avg_entries'], color = "b");

# %%
station_priorities['cumulative'] = top_weekly_totals['mean_percentage'].cumsum()
top_weekly_totals

# %%
sns.barplot(y=top_weekly_totals['STATION'], x=top_weekly_totals['cumulative'], color = "b");
plt.xlabel('Cumulative %')
