# %%
import pandas as pd
import pickle
from haversine import haversine

# %%
with open('foursquare_POIs_only.pickle', 'rb') as f:
    fsq_df = pickle.load(f)

# %%
fsq_df = fsq_df[['venueId','venueCategory', 'latitude', 'longitude']].rename(columns={'latitude':'poi_lat', 'longitude':'poi_lon'})

# %%
fsq_df.shape
# Out:
# (7523, 4)

# %%
#reducing observations to unique venues/POIs for distance calculation
fsq_df_unique = fsq_df.groupby(by='venueId', as_index=False).max()
fsq_df_unique.shape
# Out:
# (2553, 4)

# %%
with open('weekly_avg_by_station_clean.pickle', 'rb') as f:
    entry_df = pickle.load(f)

# %%
entry_df = entry_df.sort_values('ENTRIES', ascending = False)

#only interested in top 10 stations
entry_df = entry_df.iloc[0:10]

# %%
#only interested in the station names and orders
distance_df = pd.DataFrame(entry_df.STATION)
distance_df.rename(columns={'STATION': 'station'}, inplace=True)

# %%
#manually update latitude/longitude for top 10
stat_lat_lons =[(40.750326,-73.988067), # 34 st - Herald Square
                (40.755453,-73.987285), # Times Square - 42nd st
                (40.750497,-73.990877), #34 st- penn station
                (40.744376,-73.995652), #23 st - assuming 7th Ave and 23rd st 
                (40.768868,-73.980959), #59 St Columbus
                (40.763191,-73.967855), #59 St is 59 & lex
                (40.752962,-73.977219), # grand central - 42 st
                (40.715745,-74.009259), # Chambers St
                (40.758923,-73.981350), #47-50 STS ROCK
                (40.776353,-73.952861)] # 86 St

# %%
distance_df['station_lat'] = [x[0] for x in stat_lat_lons]
distance_df['station_lon'] = [x[1] for x in stat_lat_lons]
distance_df
# Out:
#              station  station_lat  station_lon
# 39   34 ST-HERALD SQ    40.750326   -73.988067
# 200   TIMES SQ-42 ST    40.755453   -73.987285
# 41    34 ST-PENN STA    40.750497   -73.990877
# 31             23 ST    40.744376   -73.995652
# 60    59 ST COLUMBUS    40.768868   -73.980959
# 59             59 ST    40.763191   -73.967855
# 143  GRD CNTRL-42 ST    40.752962   -73.977219
# 115      CHAMBERS ST    40.715745   -74.009259
# 50    47-50 STS ROCK    40.758923   -73.981350
# 74             86 ST    40.776353   -73.952861

# %%
#add column of all 1s to each df so we can merge to get all distances
distance_df['merge_column'] = 1
fsq_df_unique['merge_column'] = 1

distance_df = distance_df.merge(right=fsq_df_unique, on='merge_column')
distance_df.drop('merge_column', axis=1, inplace=True)

# %%
distance_df.head()
# Out:
#            station  station_lat  station_lon                   venueId  \
# 0  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5200eea1ee3
# 1  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5200fea1ee3
# 2  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a52010e41ee3
# 3  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5201ae61ee3
# 4  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5201be61ee3
#
#                      venueCategory    poi_lat    poi_lon
# 0                 Sushi Restaurant  40.727771 -74.000337
# 1                      Salad Place  40.739980 -73.986648
# 2  Molecular Gastronomy Restaurant  40.719649 -73.984607
# 3                 Sushi Restaurant  40.728898 -73.998128
# 4                   Clothing Store  40.722283 -73.999529

# %%
def distance_to_station(df_row):
    stat_coords = (df_row.station_lat, df_row.station_lon)
    poi_coords = (df_row.poi_lat, df_row.poi_lon)
    return haversine(stat_coords, poi_coords, miles=True)

# %%
distance_df['distance'] = distance_df.apply(distance_to_station, axis=1)

# %%
distance_df.head()
# Out:
#            station  station_lat  station_lon                   venueId  \
# 0  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5200eea1ee3
# 1  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5200fea1ee3
# 2  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a52010e41ee3
# 3  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5201ae61ee3
# 4  34 ST-HERALD SQ    40.750326   -73.988067  3fd66200f964a5201be61ee3
#
#                      venueCategory    poi_lat    poi_lon  distance
# 0                 Sushi Restaurant  40.727771 -74.000337  1.685613
# 1                      Salad Place  40.739980 -73.986648  0.718688
# 2  Molecular Gastronomy Restaurant  40.719649 -73.984607  2.127333
# 3                 Sushi Restaurant  40.728898 -73.998128  1.571412
# 4                   Clothing Store  40.722283 -73.999529  2.028399

# %%
distance_df = distance_df[distance_df.distance < 1]
distance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4014 entries, 1 to 25502
# Data columns (total 8 columns):
# station          4014 non-null object
# station_lat      4014 non-null float64
# station_lon      4014 non-null float64
# venueId          4014 non-null object
# venueCategory    4014 non-null object
# poi_lat          4014 non-null float64
# poi_lon          4014 non-null float64
# distance         4014 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 282.2+ KB

# %%
with open('distance_df_v2.pickle','wb') as f:
    pickle.dump(distance_df, f)

# %%
distance_df.groupby(by=['venueCategory','station'], as_index=False).count().sort_values(['venueCategory','poi_lat'], ascending=[True,False])
# Out:
#           venueCategory          station  station_lat  station_lon  venueId  \
# 3          Antique Shop   47-50 STS ROCK            4            4        4
# 5          Antique Shop   59 ST COLUMBUS            4            4        4
# 9          Antique Shop   TIMES SQ-42 ST            4            4        4
# 4          Antique Shop            59 ST            3            3        3
# 8          Antique Shop  GRD CNTRL-42 ST            3            3        3
# 0          Antique Shop            23 ST            2            2        2
# 1          Antique Shop  34 ST-HERALD SQ            1            1        1
# 2          Antique Shop   34 ST-PENN STA            1            1        1
# 6          Antique Shop            86 ST            1            1        1
# 7          Antique Shop      CHAMBERS ST            1            1        1
# 11          Bridal Shop  34 ST-HERALD SQ            5            5        5
# 10          Bridal Shop            23 ST            4            4        4
# 12          Bridal Shop   34 ST-PENN STA            4            4        4
# 13          Bridal Shop   47-50 STS ROCK            4            4        4
# 18          Bridal Shop   TIMES SQ-42 ST            4            4        4
# 15          Bridal Shop   59 ST COLUMBUS            3            3        3
# 17          Bridal Shop  GRD CNTRL-42 ST            3            3        3
# 14          Bridal Shop            59 ST            2            2        2
# 16          Bridal Shop      CHAMBERS ST            2            2        2
# 20       Clothing Store  34 ST-HERALD SQ          219          219      219
# 19       Clothing Store            23 ST          212          212      212
# 21       Clothing Store   34 ST-PENN STA          212          212      212
# 22       Clothing Store   47-50 STS ROCK          201          201      201
# 27       Clothing Store  GRD CNTRL-42 ST          194          194      194
# 28       Clothing Store   TIMES SQ-42 ST          183          183      183
# 26       Clothing Store      CHAMBERS ST          170          170      170
# 23       Clothing Store            59 ST          149          149      149
# 24       Clothing Store   59 ST COLUMBUS          149          149      149
# 25       Clothing Store            86 ST           47           47       47
# 29       Cosmetics Shop            23 ST           60           60       60
# ..                  ...              ...          ...          ...      ...
# 95   Salon / Barbershop  GRD CNTRL-42 ST           72           72       72
# 90   Salon / Barbershop   47-50 STS ROCK           71           71       71
# 87   Salon / Barbershop            23 ST           69           69       69
# 89   Salon / Barbershop   34 ST-PENN STA           67           67       67
# 96   Salon / Barbershop   TIMES SQ-42 ST           67           67       67
# 88   Salon / Barbershop  34 ST-HERALD SQ           66           66       66
# 91   Salon / Barbershop            59 ST           53           53       53
# 92   Salon / Barbershop   59 ST COLUMBUS           45           45       45
# 94   Salon / Barbershop      CHAMBERS ST           33           33       33
# 93   Salon / Barbershop            86 ST           15           15       15
# 97        Spa / Massage            23 ST           53           53       53
# 106       Spa / Massage   TIMES SQ-42 ST           46           46       46
# 99        Spa / Massage   34 ST-PENN STA           45           45       45
# 105       Spa / Massage  GRD CNTRL-42 ST           44           44       44
# 100       Spa / Massage   47-50 STS ROCK           43           43       43
# 98        Spa / Massage  34 ST-HERALD SQ           42           42       42
# 101       Spa / Massage            59 ST           27           27       27
# 104       Spa / Massage      CHAMBERS ST           25           25       25
# 102       Spa / Massage   59 ST COLUMBUS           23           23       23
# 103       Spa / Massage            86 ST           14           14       14
# 108    Sushi Restaurant  34 ST-HERALD SQ           60           60       60
# 109    Sushi Restaurant   34 ST-PENN STA           59           59       59
# 116    Sushi Restaurant   TIMES SQ-42 ST           58           58       58
# 115    Sushi Restaurant  GRD CNTRL-42 ST           55           55       55
# 110    Sushi Restaurant   47-50 STS ROCK           53           53       53
# 107    Sushi Restaurant            23 ST           50           50       50
# 111    Sushi Restaurant            59 ST           45           45       45
# 112    Sushi Restaurant   59 ST COLUMBUS           33           33       33
# 113    Sushi Restaurant            86 ST           19           19       19
# 114    Sushi Restaurant      CHAMBERS ST           17           17       17
#
#      poi_lat  poi_lon  distance
# 3          4        4         4
# 5          4        4         4
# 9          4        4         4
# 4          3        3         3
# 8          3        3         3
# 0          2        2         2
# 1          1        1         1
# 2          1        1         1
# 6          1        1         1
# 7          1        1         1
# 11         5        5         5
# 10         4        4         4
# 12         4        4         4
# 13         4        4         4
# 18         4        4         4
# 15         3        3         3
# 17         3        3         3
# 14         2        2         2
# 16         2        2         2
# 20       219      219       219
# 19       212      212       212
# 21       212      212       212
# 22       201      201       201
# 27       194      194       194
# 28       183      183       183
# 26       170      170       170
# 23       149      149       149
# 24       149      149       149
# 25        47       47        47
# 29        60       60        60
# ..       ...      ...       ...
# 95        72       72        72
# 90        71       71        71
# 87        69       69        69
# 89        67       67        67
# 96        67       67        67
# 88        66       66        66
# 91        53       53        53
# 92        45       45        45
# 94        33       33        33
# 93        15       15        15
# 97        53       53        53
# 106       46       46        46
# 99        45       45        45
# 105       44       44        44
# 100       43       43        43
# 98        42       42        42
# 101       27       27        27
# 104       25       25        25
# 102       23       23        23
# 103       14       14        14
# 108       60       60        60
# 109       59       59        59
# 116       58       58        58
# 115       55       55        55
# 110       53       53        53
# 107       50       50        50
# 111       45       45        45
# 112       33       33        33
# 113       19       19        19
# 114       17       17        17
#
# [117 rows x 8 columns]
